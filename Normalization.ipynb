# %% [markdown]
# <a href="https://colab.research.google.com/github/anshii1311/Machine_learning/blob/main/Normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x=np.array([3,4])
#magnitude
norm=np.linalg.norm(x);
#normalize
unit_vector=x/norm
print("magnitude",norm)
print("unit vector",unit_vector)
# Out:
# magnitude 5.0
# unit vector [0.6 0.8]
